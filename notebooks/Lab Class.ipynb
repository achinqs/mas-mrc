# %%
# %pylab osx
print "foo"
import control
from control.matlab import *
import matplotlib.pyplot as plt

tfK = lambda K: tf(K, [1,6,K+8])
    
sys1 = tfK(0.001)
sys2 = tfK(1)
sys3 = tfK(10)
sys3 = tfK(10000)

try:
    plt.plot(pzmap(sys1))
except ValueError:
    print "error, moving on"
#plt.plot(sys2)

#plt.plot(pzmap(sys3))

#plt.plot(pzmap(sys4))

plt.show()
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: MacOSX].
# For more information, type 'help(pylab)'.
# foo
# error, moving on

# %%
import control
from control.matlab import *
import numpy as np

sys1 = tf(np.array([1]),np.array([1,6,8]))
sys2 = tf([1,1],[1,6,8])
sys3 = tf([1,6,5],[1,6,8])
sys4 = tf([1,9,20],[1,3,2])
sys5 = tf([1,9,20],[1,3,2,0])
sys6 = tf([1,3],[1,7,14,8,0])

#fig, ax = plt.subplots(6,)



try:
    #ax[1] = plt.plot(rlocus(sys1))
    #ax[2] = plt.plot(rlocus(sys2))
    #ax[3] = plt.plot(rlocus(sys3))
    #ax[4] = plt.plot(rlocus(sys4))
    plt.xlim([-20,5])
    plt.plot(rlocus(sys5))
    #ax[6] = plt.plot(rlocus(sys6))
except ValueError:
    print "there was an error but we don't care. some sort of ValueError"
#plt.subplot(222)
#plt.plot(rlocus(sys2))

#plt.subplot(rlocus(sys3))
#plt.plot(rlocus(sys4))
#plt.plot(rlocus(sys5))
#plt.plot(rlocus(sys6))
plt.show()
# Out:
# there was an error but we don't care. some sort of ValueError

# %%
fig, ax=plt.subplots(2)

x,y = range(10),range(10)
ax[1].plot(x,y,label='mydata')
 
x,y = range(0,10),range(1,11)
ax[1].plot(x,y,label='mydata2')

x,y = range(0,10),range(2,12)
ax[1].plot(x,y,label='mydata3')

ax[1].legend()
# Out:
# Legend
